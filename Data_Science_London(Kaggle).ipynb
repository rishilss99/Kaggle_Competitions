# %% [markdown]
# ## Implementation Using Scikit-Learn

# %%
import pandas as pd
import numpy as np

# %%
train_x = pd.read_csv('Data_Science_London_dataset(Kaggle)/train.csv')
train_y = pd.read_csv('Data_Science_London_dataset(Kaggle)/trainLabels.csv')
test_dataset = pd.read_csv('Data_Science_London_dataset(Kaggle)/test.csv')
train_x.head()
# Out:
#    0.29940251144353242  -1.2266241875260637  1.4984250500215328  \
# 0            -1.174176             0.332157            0.949919
# 1             1.192222            -0.414371            0.067054
# 2             1.573270            -0.580318           -0.866332
# 3            -0.613071            -0.644204            1.112558
# 4            -0.773247            -0.123227            0.047423
#
#    -1.1761503610375272  5.2898525545597037  0.20829711393323402  \
# 0            -1.285328            2.199061            -0.151268
# 1            -2.233568            3.658881             0.089007
# 2            -0.603812            3.125716             0.870321
# 3            -0.032397            3.490142            -0.011935
# 4            -0.210266           10.377793             0.526604
#
#    2.4044983672405826  1.5945062220589785  -0.051608163273514231  \
# 0           -0.427039            2.619246              -0.765884
# ...

# %%
train_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 40 columns):
# 0.29940251144353242      999 non-null float64
# -1.2266241875260637      999 non-null float64
# 1.4984250500215328       999 non-null float64
# -1.1761503610375272      999 non-null float64
# 5.2898525545597037       999 non-null float64
# 0.20829711393323402      999 non-null float64
# 2.4044983672405826       999 non-null float64
# 1.5945062220589785       999 non-null float64
# -0.051608163273514231    999 non-null float64
# 0.66323431039687908      999 non-null float64
# -1.4083700642531511      999 non-null float64
# 1.1147436351160869       999 non-null float64
# 0.91041530967390116      999 non-null float64
# 2.2181103179158135       999 non-null float64
# 4.3056427290235391       999 non-null float64
# 0.088923978050666208     999 non-null float64
# 0.1691492586690862       999 non-null float64
# 0.41344763764684195      999 non-null float64
# ...

# %%
train_y.head()
# Out:
#    1
# 0  0
# 1  0
# 2  1
# 3  0
# 4  1

# %%
print(train_x.shape)
print(train_y.shape)
# Out:
# (999, 40)
# (999, 1)

# %%
from sklearn.model_selection import train_test_split

# %%
train_tr_x,test_tr_x=train_test_split(train_x,test_size=0.3)
train_tr_y,test_tr_y=train_test_split(train_y,test_size=0.3)
